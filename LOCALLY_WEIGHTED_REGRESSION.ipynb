# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuberan123/Learning-Coding/blob/main/LOCALLY_WEIGHTED_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(2, 3, 50)
Y = np.sin(X)

# %%
plt.scatter(X, Y, alpha=0.3)
plt.show()

# %%
def local_regression(x0, X, Y, tau):
    x0 = np.array([1, x0])
    X = np.c_[np.ones(len(X)), X]
    xw = X.T * radial_kernel(x0, X, tau)
    beta = np.linalg.pinv(xw @ X) @ xw @ Y
    return x0 @ beta

# %%
def radial_kernel(x0, X, tau):
    return np.exp(np.sum((X - x0)**2, axis=1) / (-2 * tau**2))

# %%
def plot_lwr(tau):
    domain = np.linspace(2, 3, num=50)
    prediction = [local_regression(x0, X, Y, tau) for x0 in domain]
    plt.scatter(X, Y, alpha=0.5)
    plt.plot(domain, prediction, color="red")
    plt.show()

# %%
plot_lwr(0.01)
